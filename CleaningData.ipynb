# %%
# Dependencies and Setup
import pandas as pd

# %%
# File to Load (Remember to change the path if needed.)
nbaavgs1617 = "2016_17_pergame.csv"
nbaavgs1718 = "2017_18_pergame.csv"
nbaavgs1819 = "2018_19_pergame.csv"
nbaavgs1920 = "2019_20_pergame.csv"
nbaavgs2021 = "2020_21_pergame.csv"

# Read the Data and store into a Pandas DataFrame
nbaavgs1617_df = pd.read_csv(nbaavgs1617)
nbaavgs1718_df = pd.read_csv(nbaavgs1718)
nbaavgs1819_df = pd.read_csv(nbaavgs1819)
nbaavgs1920_df = pd.read_csv(nbaavgs1920)
nbaavgs2021_df = pd.read_csv(nbaavgs2021)

# %%
nbaavgs2021_df.fillna(0, inplace=True)

# %%
nbaavgs1617_df.fillna(0, inplace=True)

# %%
nbaavgs1718_df.fillna(0, inplace=True)

# %%
nbaavgs1819_df.fillna(0, inplace=True)

# %%
nbaavgs1920_df.fillna(0, inplace=True)

# %%
nbaavgs1617_df.set_index('Rk')
# Out:
#                 Player   G  GS    MP   FG  FGA    FG%   3P  3PA    3P%  ...  \
# Rk                                                                      ...
# 1         Álex Abrines  68   6  15.5  2.0  5.0  0.393  1.4  3.6  0.381  ...
# 2           Quincy Acy  38   1  14.7  1.8  4.5  0.412  1.0  2.4  0.411  ...
# 3         Steven Adams  80  80  29.9  4.7  8.2  0.571  0.0  0.0  0.000  ...
# 4        Arron Afflalo  61  45  25.9  3.0  6.9  0.440  1.0  2.5  0.411  ...
# 5        Alexis Ajinça  39  15  15.0  2.3  4.6  0.500  0.0  0.1  0.000  ...
# ..                 ...  ..  ..   ...  ...  ...    ...  ...  ...    ...  ...
# 482        Cody Zeller  62  58  27.8  4.1  7.1  0.571  0.0  0.0  0.000  ...
# 483       Tyler Zeller  51   5  10.3  1.5  3.1  0.494  0.0  0.0  0.000  ...
# 484  Stephen Zimmerman  19   0   5.7  0.5  1.6  0.323  0.0  0.0  0.000  ...
# 485        Paul Zipser  44  18  19.2  2.0  5.0  0.398  0.8  2.3  0.333  ...
# ...

# %%
nbaavgs1718_df.set_index('Rk')
# Out:
#              Player   G  GS    MP   FG  FGA    FG%   3P  3PA    3P%  ...  TRB  \
# Rk                                                                   ...
# 487    Álex Abrines  75   8  15.1  1.5  3.9  0.395  1.1  2.9  0.380  ...  1.5
# 488      Quincy Acy  70   8  19.4  1.9  5.2  0.356  1.5  4.2  0.349  ...  3.7
# 489    Steven Adams  76  76  32.7  5.9  9.4  0.629  0.0  0.0  0.000  ...  9.0
# 490     Bam Adebayo  69  19  19.8  2.5  4.9  0.512  0.0  0.1  0.000  ...  5.5
# 491   Arron Afflalo  53   3  12.9  1.2  3.1  0.401  0.5  1.3  0.386  ...  1.2
# ...             ...  ..  ..   ...  ...  ...    ...  ...  ...    ...  ...  ...
# 1022    Cody Zeller  33   0  19.0  2.6  4.7  0.545  0.1  0.1  0.667  ...  5.4
# 1023   Tyler Zeller  66  34  16.8  2.8  5.1  0.560  0.2  0.4  0.357  ...  4.6
# 1024    Paul Zipser  54  12  15.3  1.5  4.3  0.346  0.7  2.0  0.336  ...  2.4
# 1025     Ante Žižić  32   2   6.7  1.5  2.1  0.731  0.0  0.0  0.000  ...  1.9
# ...

# %%
nbaavgs1819_df.set_index('Rk')
# Out:
#             Player   G  GS    MP   FG   FGA    FG%   3P  3PA    3P%  ...  TRB  \
# Rk                                                                   ...
# 1027  Álex Abrines  31   2  19.0  1.8   5.1  0.357  1.3  4.1  0.323  ...  1.5
# 1028    Quincy Acy  10   0  12.3  0.4   1.8  0.222  0.2  1.5  0.133  ...  2.5
# 1029  Jaylen Adams  34   1  12.6  1.1   3.2  0.345  0.7  2.2  0.338  ...  1.8
# 1030  Steven Adams  80  80  33.4  6.0  10.1  0.595  0.0  0.0  0.000  ...  9.5
# 1031   Bam Adebayo  82  28  23.3  3.4   5.9  0.576  0.0  0.2  0.200  ...  7.3
# ...            ...  ..  ..   ...  ...   ...    ...  ...  ...    ...  ...  ...
# 1552    Trae Young  81  81  30.9  6.5  15.5  0.418  1.9  6.0  0.324  ...  3.7
# 1553   Cody Zeller  49  47  25.4  3.9   7.0  0.551  0.1  0.4  0.273  ...  6.8
# 1554  Tyler Zeller   6   1  15.5  2.7   5.0  0.533  0.0  0.2  0.000  ...  4.0
# 1555    Ante Žižić  59  25  18.3  3.1   5.6  0.553  0.0  0.0  0.000  ...  5.4
# ...

# %%
nbaavgs1920_df.set_index('Rk')
# Out:
#                         Player   G  GS    MP   FG   FGA    FG%   3P  3PA  \
# Rk
# 1557              Steven Adams  63  63  26.7  4.5   7.6  0.592  0.0  0.0
# 1558               Bam Adebayo  72  72  33.6  6.1  11.0  0.557  0.0  0.2
# 1559         LaMarcus Aldridge  53  53  33.1  7.4  15.0  0.493  1.2  3.0
# 1560            Kyle Alexander   2   0   6.5  0.5   1.0  0.500  0.0  0.0
# 1561  Nickeil Alexander-Walker  47   1  12.6  2.1   5.7  0.368  1.0  2.8
# ...                        ...  ..  ..   ...  ...   ...    ...  ...  ...
# 2081                Trae Young  60  60  35.3  9.1  20.8  0.437  3.4  9.5
# 2082               Cody Zeller  58  39  23.1  4.3   8.3  0.524  0.3  1.3
# 2083              Tyler Zeller   2   0   2.0  0.5   2.0  0.250  0.0  0.0
# 2084                Ante Žižić  22   0  10.0  1.9   3.3  0.569  0.0  0.0
# 2085               Ivica Zubac  72  70  18.4  3.3   5.3  0.613  0.0  0.0
#
#         3P%  ...   TRB  AST  STL  BLK  TOV   PF   PTS   PER   BPM  VORP
# ...

# %%
nbaavgs2021_df.set_index('Rk')
# Out:
#                  Player   G  GS    MP   FG   FGA    FG%   3P  3PA    3P%  ...  \
# Rk                                                                        ...
# 2086   Precious Achiuwa  61   4  12.1  2.0   3.7  0.544  0.0  0.0  0.000  ...
# 2087       Jaylen Adams   7   0   2.6  0.1   1.1  0.125  0.0  0.3  0.000  ...
# 2088       Steven Adams  58  58  27.7  3.3   5.3  0.614  0.0  0.1  0.000  ...
# 2089        Bam Adebayo  64  64  33.5  7.1  12.5  0.570  0.0  0.1  0.250  ...
# 2090  LaMarcus Aldridge  26  23  25.9  5.4  11.4  0.473  1.2  3.1  0.388  ...
# ...                 ...  ..  ..   ...  ...   ...    ...  ...  ...    ...  ...
# 2621       Delon Wright  63  39  27.7  3.8   8.2  0.463  1.0  2.7  0.372  ...
# 2622     Thaddeus Young  68  23  24.3  5.4   9.7  0.559  0.2  0.7  0.267  ...
# 2623         Trae Young  63  63  33.7  7.7  17.7  0.438  2.2  6.3  0.343  ...
# 2624        Cody Zeller  48  21  20.9  3.8   6.8  0.559  0.1  0.6  0.143  ...
# ...

# %%
nbaavgs1617_df.to_excel('2016_17_nbaavgs.xlsx', encoding='utf-8', index = False)

# %%
nbaavgs1718_df.to_excel('2017_18_nbaavgs.xlsx', encoding='utf-8', index = False)

# %%
nbaavgs1819_df.to_excel('2018_19_nbaavgs.xlsx', encoding='utf-8', index = False)

# %%
nbaavgs1920_df.to_excel('2019_20_nbaavgs.xlsx', encoding='utf-8', index = False)

# %%
nbaavgs2021_df.to_excel('2020_21_nbaavgs.xlsx', encoding='utf-8', index = False)
